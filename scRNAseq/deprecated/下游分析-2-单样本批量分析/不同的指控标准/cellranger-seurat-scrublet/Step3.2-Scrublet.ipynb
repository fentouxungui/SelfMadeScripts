# %%
# %matplotlib inline
import scrublet as scr
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import os
import re
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/xilab/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# >[scrublet_basics.ipynb](https://github.com/AllonKleinLab/scrublet/blob/master/examples/scrublet_basics.ipynb)

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rc('font', size=14)
plt.rcParams['pdf.fonttype'] = 42

# %%
if not os.path.exists("./Raw_Scrublet"):
    os.mkdir("./Raw_Scrublet")
    
for Acounts_matrix in os.listdir("./Raw_mtx/"):
    if Acounts_matrix.endswith('UMI.mtx'):
        print("***** " + Acounts_matrix + " *****")
        counts_matrix = scipy.io.mmread("./Raw_mtx/" + Acounts_matrix).T.tocsc()
        scrub = scr.Scrublet(counts_matrix, expected_doublet_rate=0.06)
        doublet_scores, predicted_doublets = scrub.scrub_doublets(min_counts=2, 
                                                          min_cells=3, 
                                                          min_gene_variability_pctl=85, 
                                                          n_prin_comps=30)
        plt.show(scrub.plot_histogram())
        np.savetxt("./Raw_Scrublet/" + Acounts_matrix.replace("UMI.mtx","scrublet.score.txt"),scrub.doublet_scores_obs_)
# Out:
# ***** APCmin_Mouse_jeju_Tumor_Mesen_200421.UMI.mtx *****
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# /home/xilab/miniconda3/lib/python3.7/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 31.9%
# Overall doublet rate:
# 	Expected   = 6.0%
# 	Estimated  = 2.3%
# Elapsed time: 2.7 seconds
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# ***** APCmin_Mouse_duo_Para_Epi_200421.UMI.mtx *****
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# ...
