# %%
import anndata
import scvelo as scv
import pandas as pd
import numpy as np
import matplotlib as plt
# %load_ext rpy2.ipython
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
# /home/xilab/miniconda3/lib/python3.7/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %% [markdown]
# # Integrating Loom File and Meta-data

# %%
sample_obs = pd.read_csv("cellID_obs.csv")
umap = pd.read_csv("cell_embeddings.csv")
cell_clusters = pd.read_csv("clusters.csv")

# %%
sample = anndata.read_loom("../../../../../Merge-Batch1-and-Batch2-loom-files/Human_merge_Batch1_and_Batch2.loom")
sample
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 63837 × 33538
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
# Only keep cells from seurat object
sample = sample[np.isin(sample.obs.index,sample_obs["x"])]
sample
# Out:
# View of AnnData object with n_obs × n_vars = 1119 × 33538
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
# order cells from umap coordinate
sample_index = pd.DataFrame(sample.obs.index)
sample_index = sample_index.rename(columns = {0:'Cell ID'})
umap = umap.rename(columns = {'Unnamed: 0':'Cell ID'})
umap_ordered = sample_index.merge(umap,on="Cell ID")

# %%
# Add umap coordinate to Anndata object
umap_ordered = umap_ordered.iloc[:,1:]
sample.obsm['X_umap'] = umap_ordered.values
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# reorder cell_cluster
cell_clusters = cell_clusters.rename(columns = {'cells':'Cell ID'})
clusters_ordered = sample_index.merge(cell_clusters,on="Cell ID")

# %%
clusters_ordered
# Out:
#                           Cell ID          Unnamed: 0 orig.ident  nCount_RNA  \
# 0     PH3-CD326:TATTGGGCATACTGACx  TATTGGGCATACTGAC_1  PH3-CD326       19646
# 1     PH3-CD326:TCTACCGCAACCGTGCx  TCTACCGCAACCGTGC_1  PH3-CD326       10485
# 2     PH3-mesen:AATTTCCTCTGAGGTTx  AATTTCCTCTGAGGTT_5  PH3-mesen       35206
# 3     PH3-mesen:AAAGGTATCCAAGCCGx  AAAGGTATCCAAGCCG_5  PH3-mesen       13030
# 4     PH3-mesen:AAGCCATAGCGTTCATx  AAGCCATAGCGTTCAT_5  PH3-mesen       23235
# ...                           ...                 ...        ...         ...
# 1114  PH4-mesen:TTCCGGTAGTCACTCAx  TTCCGGTAGTCACTCA_6  PH4-mesen       10591
# 1115  PH4-mesen:TTATTGCGTAGGTGCAx  TTATTGCGTAGGTGCA_6  PH4-mesen       11389
# 1116  PH4-mesen:TTATTGCGTGCCTAATx  TTATTGCGTGCCTAAT_6  PH4-mesen       10871
# 1117  PH4-mesen:TTCCTTCAGTCATCGTx  TTCCTTCAGTCATCGT_6  PH4-mesen       40592
# 1118  PH4-mesen:TTGAGTGAGAAGTCTAx  TTGAGTGAGAAGTCTA_6  PH4-mesen        9084
#
#       nFeature_RNA  percent.mt  UMI.Non.mt  old_RNA_snn_res.0.5  \
# 0             4617    9.661000     17748.0                  8.0
# 1             3205   13.781593      9040.0                  8.0
# 2             6428    6.490371         NaN                  5.0
# 3             3784    7.536454         NaN                  5.0
# 4             5408    6.025393         NaN                  6.0
# ...            ...         ...         ...                  ...
# 1114          3414    8.497781         NaN                  5.0
# 1115          3831    6.655545         NaN                  5.0
# 1116          3216    9.244780         NaN                  5.0
# 1117          6703    5.247339         NaN                  5.0
# 1118          3277    8.465434         NaN                  5.0
#
#       seurat_clusters  old_RNA_snn_res.0.2  ...  old.ident  \
# 0                  11                    4  ...          4
# 1                   0                    4  ...          4
# 2                   0                    4  ...          4
# 3                   1                    4  ...          4
# 4                   2                    4  ...          4
# ...               ...                  ...  ...        ...
# 1114                0                    4  ...          4
# 1115               10                    4  ...          4
# 1116                0                    4  ...          4
# 1117                8                    4  ...          4
# 1118                2                    4  ...          4
#
#       old_RNA_snn_res.1.6  RNA_snn_res.0.2  RNA_snn_res.0.4  RNA_snn_res.0.6  \
# 0                       8                0                7                8
# 1                       9                1                1                0
# 2                       9                1                1                0
# 3                       9                1                4                3
# 4                       8                2                3                2
# ...                   ...              ...              ...              ...
# 1114                    9                1                1                0
# 1115                   29                3                2                9
# 1116                    9                1                1                0
# 1117                    8                1                5               10
# 1118                    8                2                3                2
#
#       RNA_snn_res.0.8 RNA_snn_res.1 RNA_snn_res.1.2  RNA_snn_res.1.4  \
# 0                   9            10              10               11
# 1                   0             0               0                0
# 2                   0             0               0                0
# 3                   3             3               2                1
# 4                   2             2               3                2
# ...               ...           ...             ...              ...
# 1114                0             0               0                0
# 1115                8             9               9               10
# 1116                0             0               0                0
# 1117               10             8               8                8
# 1118                2             2               3                2
#
#       RNA_snn_res.1.6
# 0                  11
# 1                   0
# 2                   0
# 3                   1
# 4                   2
# ...               ...
# 1114                0
# 1115               10
# 1116                0
# 1117                8
# 1118                2
#
# [1119 rows x 31 columns]

# %%
# Add cluster info to Anndata object
clusters_ordered = clusters_ordered.iloc[:,8]
sample.obs['clusters'] = np.array(clusters_ordered)

# %% [markdown]
# # Running RNA Velocity

# %%
sample.obs['clusters'] = sample.obs['clusters'].astype('category').values

# %%
scv.pl.proportions(sample,figsize=(10,6))

# %%
scv.pp.filter_and_normalize(sample, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(sample, n_pcs=30, n_neighbors=30)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Filtered out 25663 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Logarithmized X.
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of spliced/unspliced abundances (adata.layers)

# %%
scv.tl.velocity(sample)
# Out:
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(sample)
# Out:
# computing velocity graph
#     finished (0:00:01) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_stream(sample, basis='umap',dpi = 120)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding(sample, arrow_length=5, arrow_size=4, dpi=120)

# %% [markdown]
# # Identify important genes

# %%
scv.tl.rank_velocity_genes(sample, groupby='clusters', min_corr=.3)

df = scv.DataFrame(sample.uns['rank_velocity_genes']['names'])
df.head(20)
# Out:
# ranking velocity genes
#     finished (0:00:00) --> added
#     'rank_velocity_genes', sorted scores by group ids (adata.uns)
#     'spearmans_score', spearmans correlation scores (adata.var)
#           0         1         2            4         5        7        8  \
# 0    TGFBR2    MICAL2      CD36        PMP22     IGHA2    THSD4   CACHD1
# 1      THRB    IL18R1     ABCB1       SLC4A7      BCL2      ELN  PITPNM2
# 2     DAAM1     ICAM1      IQCK      ZNF385D      NOX4     HTR4     RIN3
# 3    TGFBR3  ARHGEF15  KIAA1671       AKAP12     IGHA1     SOX5     EMCN
# 4    ARID5B    FAM20A     RAB34         JAM3    ZNF704   MAP3K1     NAV1
# 5     ANXA1       LPP     ABCC4        LIMK2     ITIH5    GRB14  C3orf70
# 6      SRGN   FAM208B     NCALD       PIK3R1    DEPTOR   NKAIN2     PLAT
# 7    PDLIM3    METRNL      AHRR       RAB27A     EFCC1    LTBP1   DEPTOR
# 8    DOCK11      AHI1    CLASP1      PPFIBP1    NLGN4Y   PRDM16  TNFSF10
# 9       HGF      KLF7      FZD4        TSHZ2      MGLL    PLCG2    ADCY4
# 10     MLF1      ELL2    ZNF827       SEMA6B     HCLS1     PRKX      CD9
# 11   COL4A4     BAZ1A    OTUD7A         IL6R    IQGAP2   ABI3BP   JARID2
# 12     EBF3     CALD1     KANK3         RELB     RBMS3    WNT2B  NEURL1B
# 13    MEOX2    CNKSR3  ADAMTS10        SPSB1     STK10  SLC37A1     HEG1
# 14     NNMT     MCTP1    SORBS2        NDST1     RCAN2     UTRN     TNXB
# 15     ATF3     NOP16      EML1       GRPEL1    JARID2   SPATA6     AHRR
# 16  ST6GAL1      EXT1     DDX60  ADAMTS9-AS1  TMEM150C   COL8A1    APBB2
# 17  CYSLTR2     SYNJ2      VAT1       SAMD4A    FILIP1      CLU     TMC6
# 18    LMCD1      ENAH     APBB2        NOP16     P4HA1    LTC4S    P2RY8
# 19   TIPARP    ATP1B3     RSAD2      ADAMTS9  ARHGAP18    EFNA5     NKTR
#
#              9       10            11       12        13        14         15  \
# 0       DEPTOR     TC2N        SEMA3F      DSP     NCAM1      MCAM      MYO5C
# 1        APBB2    NLGN1       SEC14L1    APLNR  CDC42BPA     ZFHX3      BCAT1
# 2         NAV1    USP53         LAMB1    ITGA6    PCDH17    INPP4B       TLL1
# 3        PLCL2    GCNT1       GALNT18    ACTG1   RAPGEF5  TMEM131L    TSPAN18
# 4          FAP   FRMD4B          FJX1    MYH11     HIPK2      EPS8      DAGLB
# 5         AQP7    PDE4B        ADGRL4    BCAT1    COL6A2      CLMN    NEURL1B
# 6       PIK3R3  RAPGEF2         PLA1A     FGD6     MYO1E    ATP8B2       HIP1
# 7     TMEM150C  ADAMTS1         MYO1B     PLK2      AGMO     EMID1     ATP2B1
# 8        BTNL9  SLC37A1          XAF1   PLXND1    ADGRF5    ADGRL3     STARD8
# 9       CAMK2G    GATA6         PREX1     SNCA      MT1M     ITIH5       SYN2
# 10        AHRR  RNF144B    ST6GALNAC3    MYO1B     CPED1     MAT2A  CADM3-AS1
# 11  MIRLET7BHG   NKAIN2          GYPC   CALCRL   FAM184A      RGS6      BTBD3
# 12       KANK3  EPB41L2       TSC22D3     PKN1   ATP13A3    SEMA4B       NRP1
# 13        FLT4    EFNA5           TPO      CIT      GPX3      RND3       MYLK
# 14       ADCY4     HRH1       SIPA1L2   RNF213     DDX21       CD9       NTN4
# 15        LAYN     HTR4          INSR  NEURL1B     CADM2      DLC1      MEOX2
# 16       ABCB1      DST        ZBTB18   RNF125     LITAF    COL6A2       LYST
# 17      JARID2    WNT2B          MLEC     TESC    MAP4K3    INPP5K    TMEM154
# 18         TPO  MAP3K14  MAPKAPK5-AS1   EPSTI1    PHLDB1    CEP126        TPO
# 19     RAPGEF1    ABCG1          PXDN    SMAD1      RGS6      GJA1      RXFP1
#
#             16        17        19          20
# 0        CLIC5     EMID1       DST      ELOVL7
# 1         TBCD     PDE3B      HAS2        NAV1
# 2        ATOH8      CLMN   ANGPTL1  MIRLET7BHG
# 3        AIF1L      P3H4     EGLN3     NEURL1B
# 4         CD58    INPP4B      BCL2        CD44
# 5         PRTG    COL5A2       DMD     PITPNM2
# 6        CMTM8    ZNF618       MX2      ADGRF5
# 7       ADARB1     PMP22      MLKL      CX3CL1
# 8        FGF12   C1orf21   C3orf70       IGHA1
# 9        KCNQ1     WNT5B     TTLL7       BTNL9
# 10    BAIAP2L1      SNCA    KCNMB4       FADS3
# 11  MIRLET7BHG       JUP    PHLDB1      PTGER4
# 12     C1orf54     RAB31      NEO1       PLCG2
# 13       SOX13       AK4    FAXDC2       ADCY4
# 14       NCALD       DST  ARHGAP24      ADGRL4
# 15       PREX1  TMEM131L      ANK2      TCF7L2
# 16       AUTS2     CSRP1    PTPN13        HEG1
# 17    KIAA0355      IL6R    SEMA4B       P2RY8
# 18     PLEKHA2     NRXN3  ZDHHC11B       PODXL
# 19        NEO1   SLC12A2   COL21A1        EMCN

# %%
kwargs = dict(frameon=False, size=10, linewidth=1.5,
              add_outline='3, 0')

scv.pl.scatter(sample, df['3'][:5], ylabel='cluster-3', **kwargs)
scv.pl.scatter(sample, df['0'][:5], ylabel='cluster-0', **kwargs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-00d624be3bf1> in <module>
#       2               add_outline='3, 0')
#       3
# ----> 4 scv.pl.scatter(sample, df['3'][:5], ylabel='cluster-3', **kwargs)
#       5 scv.pl.scatter(sample, df['0'][:5], ylabel='cluster-0', **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3'

# %% [markdown]
# # Velocities in cycling progenitors

# %%
# Attention, the default genes probably are from Human.
scv.tl.score_genes_cell_cycle(sample)
scv.pl.scatter(sample, color_gradients=['S_score', 'G2M_score'], smooth=True, perc=[5, 95])

# %%
s_genes, g2m_genes = scv.utils.get_phase_marker_genes(sample)
s_genes = scv.get_df(sample[:, s_genes], 'spearmans_score', sort_values=True).index
g2m_genes = scv.get_df(sample[:, g2m_genes], 'spearmans_score', sort_values=True).index

kwargs = dict(frameon=False, ylabel='cell cycle genes')
scv.pl.scatter(sample, list(s_genes[:2]) + list(g2m_genes[:3]), **kwargs)

# %% [markdown]
# # Speed and coherence

# %%
scv.tl.velocity_confidence(sample)
keys = 'velocity_length', 'velocity_confidence'
scv.pl.scatter(sample, c=keys, cmap='coolwarm', perc=[5, 95])

# %%
df = sample.obs.groupby('clusters')[keys].mean().T
df.style.background_gradient(cmap='coolwarm', axis=1)

# %% [markdown]
# # Velocity graph and pseudotime

# %%
scv.pl.velocity_graph(sample, threshold=.1)

# %%
# how to set the starting_cell ?
x, y = scv.utils.get_cell_transitions(sample, basis='umap', starting_cell=0)
ax = scv.pl.velocity_graph(sample, c='lightgrey', edge_width=.05, show=False)
ax = scv.pl.scatter(sample, x=x, y=y, s=120, c='ascending', cmap='gnuplot', ax=ax)

# %%
scv.tl.velocity_pseudotime(sample)
scv.pl.scatter(sample, color='velocity_pseudotime', cmap='gnuplot')

# %% [markdown]
# # PAGA velocity graph

# %%
# PAGA requires to install igraph, if not done yet.
# !pip install python-igraph --upgrade --quiet

# %%
# this is needed due to a current bug - bugfix is coming soon.
sample.uns['neighbors']['distances'] = sample.obsp['distances']
sample.uns['neighbors']['connectivities'] = sample.obsp['connectivities']

scv.tl.paga(sample, groups='clusters')
df = scv.get_df(sample, 'paga/transitions_confidence', precision=2).T
df.style.background_gradient(cmap='Blues').format('{:.2g}')

# %%
scv.pl.paga(sample, basis='umap', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5)

# %%
scv.pl.paga(sample, basis='umap', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5, threshold = 0.025)

# %%
scv.pl.paga(sample, basis='umap', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5, threshold = 0.05)
